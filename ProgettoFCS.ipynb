# %%
# %%time
import numpy as np
import pandas as pd
import re
import math
import time
doc=pd.read_csv('googleplaystore.csv')
doc=doc.drop(doc.index[10472]).reset_index(drop=True)    #alla riga 10472 ho una row da eliminare
display(doc.head(),doc.shape)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
start = time.time()

# %% [markdown]
# # 1) Convert app size into number

# %%
# %%time

#definisco il pattern da cercare
m = re.compile('^(?P<number>\d+[.]*\d*)(?P<unit>[M|k])$')

#definisco la funzione per la conversione
def size2num(x):
    m1 = m.match(x)
    if m1 is None:
        return np.nan
    num = float(m1.group('number'))    
    uni = str(m1.group('unit'))
    if uni == 'M':
        return int(np.round(num * 10**6))
    if uni == 'k':
        return int(np.round(num * 10**3))
    
#applico la funzione size2num alla colonna Size
doc['Size'] = doc['Size'].apply(size2num)
display(doc.head())
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews        Size     Installs  Type Price Content Rating  \
# 0     159  19000000.0      10,000+  Free     0       Everyone
# 1     967  14000000.0     500,000+  Free     0       Everyone
# 2   87510   8700000.0   5,000,000+  Free     0       Everyone
# 3  215644  25000000.0  50,000,000+  Free     0           Teen
# 4     967   2800000.0     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %% [markdown]
# # 2) Convert the number of installs to a number

# %%
# %%time

m = re.compile('^(?P<number>\d+([,]\d*)*)[+]$')

def inst2num(x):
    m1 = m.match(x)
    if m1 is None:
        return np.nan
    num = str(m1.group('number'))   
    return int(num.replace(',', ''))

doc['Installs'] = doc['Installs'].apply(inst2num)
display(doc.head())
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews        Size    Installs  Type Price Content Rating  \
# 0     159  19000000.0     10000.0  Free     0       Everyone
# 1     967  14000000.0    500000.0  Free     0       Everyone
# 2   87510   8700000.0   5000000.0  Free     0       Everyone
# 3  215644  25000000.0  50000000.0  Free     0           Teen
# 4     967   2800000.0    100000.0  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %% [markdown]
# # 3) Transform “Varies with device” into a missing value

# %%
# %%time

doc = doc.replace('Varies with device', np.nan)
display(doc.head())
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews        Size    Installs  Type Price Content Rating  \
# 0     159  19000000.0     10000.0  Free     0       Everyone
# 1     967  14000000.0    500000.0  Free     0       Everyone
# 2   87510   8700000.0   5000000.0  Free     0       Everyone
# 3  215644  25000000.0  50000000.0  Free     0           Teen
# 4     967   2800000.0    100000.0  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# ...

# %% [markdown]
# # 4) Convert Current Ver and Android Ver into a dotted number (e.g. 4.0.3 or 4.2)

# %%
# %%time

#definisco la lista a contenente tutti gli elementi della colonna 'Current Ver' come stringhe
a = [str(i) for i in doc['Current Ver']]
#sfrutto la list comprehension: re.findall restituisce il pattern indicato nel suo argomento; se lo trova con re.search.
#se non lo trova restituisco nan.
lst = [re.findall(r'\d+[.][.|\d]*',x)[-1].strip('.') if re.search(r'\d+[.][.|\d]*',x) else np.nan for x in a ]
doc['Current Ver'] = lst

#stessa cosa per 'Android Ver'
a = [str(i) for i in doc['Android Ver']]
lst = [re.findall(r'\d+[.][.|\d]*',x)[-1].strip('.') if re.search(r'\d+[.][.|\d]*',x) else np.nan for x in a ]
doc['Android Ver'] = lst
display(doc.head(),doc.tail())
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews        Size    Installs  Type Price Content Rating  \
# 0     159  19000000.0     10000.0  Free     0       Everyone
# 1     967  14000000.0    500000.0  Free     0       Everyone
# 2   87510   8700000.0   5000000.0  Free     0       Everyone
# 3  215644  25000000.0  50000000.0  Free     0           Teen
# 4     967   2800000.0    100000.0  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver Android Ver
# ...

# %% [markdown]
# # 5) Remove the duplicates

# %%
# %%time

doc2=doc.groupby(['App']).size().reset_index(name='counts')  #mi da il numero delle occorrenze per ogni App

display(doc2[doc2['counts'] >1].head(10))    #printo tutte le righe che hanno almeno due occorrenze per nome di App
# Out:
#                                  App  counts
# 7              10 Best Foods for You       2
# 20        1800 Contacts - Lens Store       2
# 29        2017 EMRA Antibiotic Guide       2
# 35      21-Day Meditation Experience       2
# 57           365Scores - Live Scores       2
# 78            420 BZ Budeze Delivery       2
# 101                      8 Ball Pool       7
# 103     8fit Workouts & Meal Planner       2
# 104  95Live -SG#1 Live Streaming App       2
# 111          A Manual of Acupuncture       2
# Wall time: 43.9 ms

# %%
# %%time

# 8 Ball Pool ha ad es. 7 occorrenze, quello che cambia sono le reviews e in un caso anche Category.        
display(doc[doc["App"] == '8 Ball Pool'])
# Out:
#               App Category  Rating   Reviews        Size     Installs  Type  \
# 1675  8 Ball Pool     GAME     4.5  14198297  52000000.0  100000000.0  Free
# 1703  8 Ball Pool     GAME     4.5  14198602  52000000.0  100000000.0  Free
# 1755  8 Ball Pool     GAME     4.5  14200344  52000000.0  100000000.0  Free
# 1844  8 Ball Pool     GAME     4.5  14200550  52000000.0  100000000.0  Free
# 1871  8 Ball Pool     GAME     4.5  14201891  52000000.0  100000000.0  Free
# 1970  8 Ball Pool     GAME     4.5  14201604  52000000.0  100000000.0  Free
# 3953  8 Ball Pool   SPORTS     4.5  14184910  52000000.0  100000000.0  Free
#
#      Price Content Rating  Genres   Last Updated Current Ver Android Ver
# 1675     0       Everyone  Sports  July 31, 2018       4.0.0       4.0.3
# 1703     0       Everyone  Sports  July 31, 2018       4.0.0       4.0.3
# 1755     0       Everyone  Sports  July 31, 2018       4.0.0       4.0.3
# ...

# %% [markdown]
# Per considerare i duplicati, farei riferimento al nome App. Gli altri attributi variano da verisone a ver. Infatti, ad esempio Current Ver e Android Ver sono spesso nan e quindi non utili; Category spesso varia tra duplicati; ugualmente varia Reviews, cosa che teoricamente dovrebbe influenzare anche Rating...
#
# Sui duplicati devo inoltre porre la condizione di tenere quelli con un n maggiore di Reviews.

# %%
# %%time

#converto le Reviews in  numero
doc.Reviews = doc.Reviews.apply(pd.to_numeric)
#sto ordinando per Reviews -> in caso di duplicati, quello con maggior Reviews sarà in fondo.
doc=doc.sort_values(['Reviews'])             
display(doc.dtypes)

doc=doc.drop_duplicates(subset=['App'], keep = 'last')
#tenere l'ultimo mi assicura che tengo quello con maggiori Reviews
doc = doc.sort_index()
doc = doc.reset_index(drop=True) #resetto l'indice per evitare 'salti'
display(doc.head(),doc.shape)
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size              float64
# Installs          float64
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 2                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 3              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 4                         Paper flowers instructions  ART_AND_DESIGN     4.4
#
#    Reviews        Size    Installs  Type Price Content Rating  \
# 0      159  19000000.0     10000.0  Free     0       Everyone
# ...

# %% [markdown]
# # 6) For each category, compute the number of apps

# %%
# %%time

doc.groupby('Category').size().sort_values(ascending=False)
# Out:
# Wall time: 6.97 ms
# Category
# FAMILY                 1877
# GAME                    945
# TOOLS                   829
# BUSINESS                420
# MEDICAL                 395
# PERSONALIZATION         376
# PRODUCTIVITY            374
# LIFESTYLE               369
# FINANCE                 345
# SPORTS                  325
# COMMUNICATION           315
# HEALTH_AND_FITNESS      288
# PHOTOGRAPHY             281
# NEWS_AND_MAGAZINES      254
# SOCIAL                  239
# BOOKS_AND_REFERENCE     222
# TRAVEL_AND_LOCAL        219
# SHOPPING                202
# DATING                  170
# VIDEO_PLAYERS           164
# MAPS_AND_NAVIGATION     131
# FOOD_AND_DRINK          112
# EDUCATION               106
# ENTERTAINMENT            86
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       84
# WEATHER                  79
# HOUSE_AND_HOME           73
# EVENTS                   64
# ART_AND_DESIGN           61
# PARENTING                60
# COMICS                   56
# ...

# %% [markdown]
# # 7) For each category, compute the average rating

# %%
# %%time

doc.groupby('Category').Rating.mean().sort_values(ascending=False)
# Out:
# Wall time: 6.98 ms
# Category
# EVENTS                 4.435556
# ART_AND_DESIGN         4.359322
# EDUCATION              4.351429
# BOOKS_AND_REFERENCE    4.344970
# PERSONALIZATION        4.332215
# PARENTING              4.300000
# BEAUTY                 4.278571
# SOCIAL                 4.247291
# GAME                   4.244432
# WEATHER                4.243056
# HEALTH_AND_FITNESS     4.243033
# SHOPPING               4.230556
# SPORTS                 4.216154
# AUTO_AND_VEHICLES      4.190411
# FAMILY                 4.183898
# PRODUCTIVITY           4.183389
# COMICS                 4.181481
# LIBRARIES_AND_DEMO     4.178125
# FOOD_AND_DRINK         4.171277
# MEDICAL                4.165862
# PHOTOGRAPHY            4.155894
# HOUSE_AND_HOME         4.140984
# ENTERTAINMENT          4.129070
# NEWS_AND_MAGAZINES     4.121569
# COMMUNICATION          4.121484
# FINANCE                4.115563
# BUSINESS               4.098479
# LIFESTYLE              4.093355
# ...

# %% [markdown]
# # 8) Create two dataframes: one for the genres and one bridging apps and genres. So that, for instance, the app Pixel Draw - Number Art Coloring Book appears twice in the bridging table, once for Art & Design, once for Creativity

# %%
# %%time

#creo il df dei Generi.
#Split divide ogni valore di 'Genres' che contiene un ; in due valori salvati in due colonne diverse.
gen = pd.DataFrame([genres.split(';') for genres in doc.Genres])
gen.columns = ['gen1', 'gen2']
display(gen.head(10))
# Out:
#            gen1        gen2
# 0  Art & Design        None
# 1  Art & Design        None
# 2  Art & Design        None
# 3  Art & Design  Creativity
# 4  Art & Design        None
# 5  Art & Design        None
# 6  Art & Design        None
# 7  Art & Design        None
# 8  Art & Design  Creativity
# 9  Art & Design        None
# Wall time: 59.9 ms

# %%
# %%time

#ora creo la bridging table di App più i generi
app = pd.DataFrame(doc['App'])

#applico un merge prima e poi un melt
#merge unisce app con gen; melt poi crea due righe nel caso ci siano due generi per una App.
bg = pd.merge(app, gen,left_index=True,right_index=True).melt(id_vars = ['App'], value_name = "Genres")
bg=bg.drop(columns = "variable").dropna().reset_index(drop=True)
display(bg.head(10))
# Out:
#                                                  App        Genres
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  Art & Design
# 1  U Launcher Lite – FREE Live Cool Themes, Hide ...  Art & Design
# 2                              Sketch - Draw & Paint  Art & Design
# 3              Pixel Draw - Number Art Coloring Book  Art & Design
# 4                         Paper flowers instructions  Art & Design
# 5            Smoke Effect Photo Maker - Smoke Editor  Art & Design
# 6                                   Infinite Painter  Art & Design
# 7                               Garden Coloring Book  Art & Design
# 8                      Kids Paint Free - Drawing Fun  Art & Design
# 9                            Text on Photo - Fonteee  Art & Design
# Wall time: 48.9 ms

# %%
# %%time

display(bg[bg["App"] == "Pixel Draw - Number Art Coloring Book"]) #la richiesta è soddisfatta
# Out:
#                                         App        Genres
# 3     Pixel Draw - Number Art Coloring Book  Art & Design
# 9659  Pixel Draw - Number Art Coloring Book    Creativity
# Wall time: 22.9 ms

# %% [markdown]
# # 9) For each genre, create a new column of the original dataframe. The new columns must have boolean values (True if the app has a given genre)

# %%
# %%time

#creo doc3 concatenando a doc le dummy variables delle colonne gen1 e gen2 del dataframe dei generi.
doc3 = pd.concat([doc, pd.get_dummies(gen["gen1"], dtype = "bool")], axis= 1)
doc3 = pd.concat([doc3, pd.get_dummies(gen["gen2"], dtype = "bool")], axis= 1).drop(columns='Genres')

pd.set_option('display.max_columns',66)
display(doc3.head())    #si noti come Pixel Draw - Number Art Coloring Book sia T in Art & Design e in Creativity
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 2                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 3              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 4                         Paper flowers instructions  ART_AND_DESIGN     4.4
#
#    Reviews        Size    Installs  Type Price Content Rating  \
# 0      159  19000000.0     10000.0  Free     0       Everyone
# 1    87510   8700000.0   5000000.0  Free     0       Everyone
# 2   215644  25000000.0  50000000.0  Free     0           Teen
# 3      967   2800000.0    100000.0  Free     0       Everyone
# 4      167   5600000.0     50000.0  Free     0       Everyone
#
#       Last Updated Current Ver Android Ver  Action  Adventure  Arcade  \
# ...

# %% [markdown]
# # 10) For each genre, compute the average rating. What is the genre with highest average?

# %%
# %%time

#utilizzo lo stesso procedimento dell'esercizio 8, con Rating al posto di App
rating = pd.DataFrame(doc['Rating'])

bg2 = pd.merge(rating, gen,left_index = True,right_index=True).melt(id_vars = ['Rating'], value_name = "Genres")
bg2=bg2.drop(columns = "variable").dropna().reset_index(drop=True)

display(bg2.head(10))
# Out:
#    Rating        Genres
# 0     4.1  Art & Design
# 1     4.7  Art & Design
# 2     4.5  Art & Design
# 3     4.3  Art & Design
# 4     4.4  Art & Design
# 5     3.8  Art & Design
# 6     4.1  Art & Design
# 7     4.4  Art & Design
# 8     4.7  Art & Design
# 9     4.4  Art & Design
# Wall time: 37.9 ms

# %%
# %%time

display(bg2.groupby('Genres').Rating.mean().sort_values(ascending=False))
#Le App di genere Events sono quelle con un rating medio maggiore.
# Out:
# Genres
# Events                     4.435556
# Puzzle                     4.370732
# Brain Games                4.358065
# Art & Design               4.350000
# Books & Reference          4.343275
# Personalization            4.332215
# Word                       4.318182
# Creativity                 4.306250
# Parenting                  4.300000
# Music & Audio              4.300000
# Board                      4.291228
# Education                  4.290290
# Action & Adventure         4.288542
# Casino                     4.286486
# Beauty                     4.278571
# Arcade                     4.277838
# Role Playing               4.272072
# Action                     4.247697
# Social                     4.247291
# Health & Fitness           4.243496
# Weather                    4.243056
# Pretend Play               4.238235
# Shopping                   4.230556
# Music & Video              4.229032
# Strategy                   4.227368
# Sports                     4.225185
# ...

# %% [markdown]
# # 11) For each app, compute the approximate income, obtain as a product of number of installs and price.

# %%
# %%time

doc.dtypes
m = re.compile('^(?P<dol>[$])*(?P<num>(\d+[.]*)*)$')

#definisco la funzione che converte il prezzo da stringa a valore numerico
def price2num(x):
    m1 = m.match(x)
    if m1 is None:
        return np.nan
    num = float(m1.group('num'))
    return num

doc.Price = doc.Price.apply(price2num)

doc.insert(loc = 8, column = 'Income', value = doc.Price * doc.Installs)   #per inserire income in una posizione specifica
display(doc.sort_values('Income',ascending=False).head(10))
# Out:
#                                 App     Category  Rating  Reviews        Size  \
# 1613                      Minecraft       FAMILY     4.5  2376564         NaN
# 4248                      I am rich    LIFESTYLE     3.8     3547   1800000.0
# 4252              I Am Rich Premium      FINANCE     4.1     1867   4700000.0
# 3034                  Hitman Sniper         GAME     4.6   408292  29000000.0
# 6258  Grand Theft Auto: San Andreas         GAME     4.4   348962  26000000.0
# 2108            Facetune - For Free  PHOTOGRAPHY     4.4    49553  48000000.0
# 4461        Sleep as Android Unlock    LIFESTYLE     4.5    23966    872000.0
# 7627            DraStic DS Emulator         GAME     4.6    87766  12000000.0
# 3303       I'm Rich - Trump Edition    LIFESTYLE     3.6      275   7300000.0
# 4250                 I am Rich Plus       FAMILY     4.0      856   8700000.0
#
#         Installs  Type   Price      Income Content Rating  \
# ...

# %% [markdown]
# # 12) For each app, compute its minimum and maximum Sentiment_polarity

# %%
# %%time

rev=pd.read_csv('googleplaystore_user_reviews.csv')
display(rev.head())
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000
# Wall time: 374 ms

# %%
# %%time

display(rev.groupby('App')['Sentiment_Polarity'].aggregate({'min', 'max'}).head(10))
# Out:
#                                                        max       min
# App
# 10 Best Foods for You                             1.000000 -0.800000
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                  0.910000 -0.112500
# 11st                                              1.000000 -1.000000
# 1800 Contacts - Lens Store                        0.838542 -0.300000
# 1LINE – One Line with One Touch                   1.000000 -0.825000
# 2018Emoji Keyboard 😂 Emoticons Lite -sticker&gif  1.000000 -0.800000
# 21-Day Meditation Experience                      0.587500 -0.265625
# 2Date Dating App, Love and matching               1.000000 -0.645833
# 2GIS: directory & navigator                       1.000000 -0.375000
# 2RedBeans                                         1.000000 -0.800000
# Wall time: 39.9 ms

# %%
end = time.time()
print(end - start)
# Out:
# 2.4873485565185547
